# %%
import os
from desktop_env.desktop_env import DesktopEnv



REGION = 'us-east-1'
screen_size = (1920, 1080)
snapshot_name = "init_state"

env = DesktopEnv(
	path_to_vm=None,
	action_space='pyautogui',
	provider_name='docker',
	region=REGION,
	snapshot_name=snapshot_name,
	screen_size=screen_size,
	headless=False,
	os_type="Ubuntu",
	require_a11y_tree=False,
	enable_proxy=False,
	client_password='',
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from desktop_env.desktop_env import DesktopEnv
#       6 REGION = 'us-east-1'
#       7 screen_size = (1920, 1080)
#
# File ~/vision_genai/train_gym/computer_use/os_world/desktop-env/src/desktop_env/__init__.py:3
#       1 from loguru import logger
# ----> 3 from .desktop import Desktop
#       4 from .desktop_args import DesktopArgs
#       6 # https://loguru.readthedocs.io/en/stable/resources/recipes.html#configuring-loguru-to-be-used-by-a-library-or-an-application
#
# File ~/vision_genai/train_gym/computer_use/os_world/desktop-env/src/desktop_env/desktop.py:4
#       1 import importlib
#       2 import time
# ----> 4 from .actor import ActorMixin
#       5 from .desktop_args import DesktopArgs
#       6 from .threading import AbstractThread
#
# File ~/vision_genai/train_gym/computer_use/os_world/desktop-env/src/desktop_env/actor.py:4
#       1 import platform
#       2 from typing import Literal
# ----> 4 import pynput
#       7 class MouseController:
#       8     def __init__(self):
#
# File ~/vision_genai/.venv_root/lib/python3.12/site-packages/pynput/__init__.py:40
#      34     import logging
#      35     return logging.getLogger('{}.{}'.format(
#      36         '.'.join(cls.__module__.split('.', 2)[:2]),
#      37         cls.__name__))
# ---> 40 from . import keyboard
#      41 from . import mouse
#
# File ~/vision_genai/.venv_root/lib/python3.12/site-packages/pynput/keyboard/__init__.py:31
#      26 import itertools
#      28 from pynput._util import backend, Events
# ---> 31 backend = backend(__name__)
#      32 KeyCode = backend.KeyCode
#      33 Key = backend.Key
#
# File ~/vision_genai/.venv_root/lib/python3.12/site-packages/pynput/_util/__init__.py:78, in backend(package)
#      75         if module in RESOLUTIONS:
#      76             resolutions.append(RESOLUTIONS[module])
# ---> 78 raise ImportError('this platform is not supported: {}'.format(
#      79     '; '.join(str(e) for e in errors)) + ('\n\n'
#      80         'Try one of the following resolutions:\n\n'
#      81         + '\n\n'.join(
#      82             ' * {}'.format(s)
#      83             for s in resolutions))
#      84         if resolutions else '')
#
# ImportError: this platform is not supported: ('failed to acquire X connection: Bad display name ""', DisplayNameError(''))
#
# Try one of the following resolutions:
#
#  * Please make sure that you have an X server running, and that the DISPLAY environment variable is set correctly
